# %% [markdown]
# <a href="https://colab.research.google.com/github/momokid/BuildSDGForAndela/blob/master/PythonOpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/misbah4064/opencvTutorial.git
# %cd opencvTutorial/
from IPython.display import clear_output
clear_output()

# %% [markdown]
# ## **Lesson 1: Changing Profile Color**

# %%
import cv2
from google.colab.patches import cv2_imshow

#Colorful image
image =cv2.imread("images/color.jpg")
cv2_imshow(image)
print(image.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=640x476 at 0x7F127050B3D0>
# (476, 640, 3)

# %%
#Make the image grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
print(gray.shape)
# Out:
# <PIL.Image.Image image mode=L size=640x476 at 0x7F1270531210>
# (476, 640)
